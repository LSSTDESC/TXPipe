# %%
import pyarrow.parquet as pq
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append("TXPipe")
import txpipe
from txpipe.utils.splitters import DynamicSplitter
from astropy.table import Table
import h5py
from astropy.io import fits

# %%
data_dir = "/Users/jzuntz/src/euclid/data"
f1 = fits.open(f"{data_dir}/COSMOS2020_CLASSIC_R1_v2.2_p3.fits")
f2 = fits.open(f"{data_dir}/COSMOS2020_CLASSIC_R1_v2.2_LEPHARE_PZ_p3.fits")

# %%
d = f2[0].data[:1000]
z = f2[0].data[0, 1:]

# %%
f2[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 1002
# NAXIS2  =              1720701
# EXTEND  =                    T
# PRODCATG= 'ANCILLARY.IMAGE'
# CHECKSUM= 'DjM5DhJ5DhJ5DhJ5'   / HDU checksum updated 2022-05-09T20:46:00
# DATASUM = '4048406775'         / data unit checksum updated 2022-05-09T20:46:00
# COMMENT Headers updated for Phase 3 by phase3_cosmos2020.py
# COMMENT First column contains object ID
# COMMENT First row contains corresponding redshift for p(z)
# COMMENT 2022-05-09T18:44:35.030 = UT time when phase3_cosmos2020.py was run
# COMMENT 2021-07-08T11:10:33.000 = UT modification time of input file

# %%
cdf = d[1:50, 1:]

# %%
cdf.shape
# Out:
# (49, 1001)

# %%
plt.plot(z, cdf[20])

# %%
cdf.shape
# Out:
# (49, 1001)

# %%
cdf.argmax(axis=1).shape
# Out:
# (49,)
